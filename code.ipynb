# %%
import json

# %%
with open('train.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

# %%
data['data'][0]
# Out:
# {'id': 0,
#  'noisy_add': 'đông lân 1 , phường bà điểm , hồ chí minh',
#  'std_add': {'1580': {'street': 'đông lân 1',
#    'city': 'hồ chí minh',
#    'id': 1580,
#    'district': 'hóc môn',
#    'ward': 'None'}}}

# %%
def gen_data(data_file, num_sample):
    with open(data_file, 'r', encoding='utf-8') as f:
        data = json.load(f)

    x = dict()
    x['data'] = []
    for i in range(num_sample):
        x['data'].append(data['data'][i])
    return x

# %%
train_data = gen_data('train.json', 1000)
with open('Siameser/Data/train.json', 'w', encoding='utf-8') as f:
    json.dump(train_data, f, ensure_ascii=False, indent=4)

# %%
test_data = gen_data('test.json', 500)
with open('Siameser/Data/test.json', 'w', encoding='utf-8') as f:
    json.dump(test_data, f, ensure_ascii=False, indent=4)

# %%
with open('Siameser/Data/RAT_DATA_MAIN.json', 'r', encoding='utf-8') as f:
    RAT_DATA = json.load(f)

# %%
RAT_DATA
# Out:
# {'data': [{'id': 0,
#    'std_add': {'street': 'đường 1',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 1 bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 1 binh chanh ho chi minh'},
#   {'id': 1,
#    'std_add': {'street': 'đường 10',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 10 bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 10 binh chanh ho chi minh'},
#   {'id': 2,
#    'std_add': {'street': 'đường 10a',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 10a bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 10a binh chanh ho chi minh'},
#   {'id': 3,
#    'std_add': {'street': 'đường 10b',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 10b bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 10b binh chanh ho chi minh'},
#   {'id': 4,
#    'std_add': {'street': 'đường 11',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 11 bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 11 binh chanh ho chi minh'},
#   {'id': 5,
#    'std_add': {'street': 'đường 12',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 12 bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 12 binh chanh ho chi minh'},
#   {'id': 6,
#    'std_add': {'street': 'đường 13',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 13 bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 13 binh chanh ho chi minh'},
#   {'id': 7,
#    'std_add': {'street': 'đường 14',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 14 bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 14 binh chanh ho chi minh'},
#   {'id': 8,
#    'std_add': {'street': 'đường 15',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 15 bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 15 binh chanh ho chi minh'},
#   {'id': 9,
#    'std_add': {'street': 'đường 16',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 16 bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 16 binh chanh ho chi minh'},
#   {'id': 10,
#    'std_add': {'street': 'đường 17',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 17 bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 17 binh chanh ho chi minh'},
#   {'id': 11,
#    'std_add': {'street': 'đường 18',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 18 bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 18 binh chanh ho chi minh'},
#   {'id': 12,
#    'std_add': {'street': 'đường 19',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 19 bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 19 binh chanh ho chi minh'},
#   {'id': 13,
#    'std_add': {'street': 'đường 1a',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 1a bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 1a binh chanh ho chi minh'},
#   {'id': 14,
#    'std_add': {'street': 'đường 1b',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 1b bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 1b binh chanh ho chi minh'},
#   {'id': 15,
#    'std_add': {'street': 'đường 1e',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 1e bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 1e binh chanh ho chi minh'},
#   {'id': 16,
#    'std_add': {'street': 'đường 2',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 2 bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 2 binh chanh ho chi minh'},
#   {'id': 17,
#    'std_add': {'street': 'đường 21',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 21 bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 21 binh chanh ho chi minh'},
#   {'id': 18,
#    'std_add': {'street': 'đường 22',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 22 bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 22 binh chanh ho chi minh'},
#   {'id': 19,
#    'std_add': {'street': 'đường 234',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 234 bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 234 binh chanh ho chi minh'},
#   {'id': 20,
#    'std_add': {'street': 'đường 24',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 24 bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 24 binh chanh ho chi minh'},
#   {'id': 21,
#    'std_add': {'street': 'đường 26',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 26 bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 26 binh chanh ho chi minh'},
#   {'id': 22,
#    'std_add': {'street': 'đường 27',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 27 bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 27 binh chanh ho chi minh'},
#   {'id': 23,
#    'std_add': {'street': 'đường 2a',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 2a bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 2a binh chanh ho chi minh'},
#   {'id': 24,
#    'std_add': {'street': 'đường 2b',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 2b bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 2b binh chanh ho chi minh'},
#   {'id': 25,
#    'std_add': {'street': 'đường 3',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 3 bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 3 binh chanh ho chi minh'},
#   {'id': 26,
#    'std_add': {'street': 'đường 33',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 33 bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 33 binh chanh ho chi minh'},
#   {'id': 27,
#    'std_add': {'street': 'đường 3a',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 3a bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 3a binh chanh ho chi minh'},
#   {'id': 28,
#    'std_add': {'street': 'đường 3b',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 3b bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 3b binh chanh ho chi minh'},
#   {'id': 29,
#    'std_add': {'street': 'đường 4',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 4 bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 4 binh chanh ho chi minh'},
#   {'id': 30,
#    'std_add': {'street': 'đường 47',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 47 bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 47 binh chanh ho chi minh'},
#   {'id': 31,
#    'std_add': {'street': 'đường 4c',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 4c bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 4c binh chanh ho chi minh'},
#   {'id': 32,
#    'std_add': {'street': 'đường 4e',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 4e bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 4e binh chanh ho chi minh'},
#   {'id': 33,
#    'std_add': {'street': 'đường 5',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 5 bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 5 binh chanh ho chi minh'},
#   {'id': 34,
#    'std_add': {'street': 'đường 50',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 50 bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 50 binh chanh ho chi minh'},
#   {'id': 35,
#    'std_add': {'street': 'đường 51',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 51 bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 51 binh chanh ho chi minh'},
#   {'id': 36,
#    'std_add': {'street': 'đường 5a',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 5a bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 5a binh chanh ho chi minh'},
#   {'id': 37,
#    'std_add': {'street': 'đường 5b',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 5b bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 5b binh chanh ho chi minh'},
#   {'id': 38,
#    'std_add': {'street': 'đường 5c',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 5c bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 5c binh chanh ho chi minh'},
#   {'id': 39,
#    'std_add': {'street': 'đường 5d',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 5d bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 5d binh chanh ho chi minh'},
#   {'id': 40,
#    'std_add': {'street': 'đường 6',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 6 bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 6 binh chanh ho chi minh'},
#   {'id': 41,
#    'std_add': {'street': 'đường 6a',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 6a bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 6a binh chanh ho chi minh'},
#   {'id': 42,
#    'std_add': {'street': 'đường 6b',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 6b bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 6b binh chanh ho chi minh'},
#   {'id': 43,
#    'std_add': {'street': 'đường 6c',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 6c bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 6c binh chanh ho chi minh'},
#   {'id': 44,
#    'std_add': {'street': 'đường 6d',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 6d bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 6d binh chanh ho chi minh'},
#   {'id': 45,
#    'std_add': {'street': 'đường 6t',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 6t bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 6t binh chanh ho chi minh'},
#   {'id': 46,
#    'std_add': {'street': 'đường 7',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 7 bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 7 binh chanh ho chi minh'},
#   {'id': 47,
#    'std_add': {'street': 'đường 7 tấn',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 7 tấn bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 7 tan binh chanh ho chi minh'},
#   {'id': 48,
#    'std_add': {'street': 'đường 8',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 8 bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 8 binh chanh ho chi minh'},
#   {'id': 49,
#    'std_add': {'street': 'đường 835b',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 835b bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 835b binh chanh ho chi minh'},
#   {'id': 50,
#    'std_add': {'street': 'đường 8a',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 8a bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 8a binh chanh ho chi minh'},
#   {'id': 51,
#    'std_add': {'street': 'đường 8b',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 8b bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 8b binh chanh ho chi minh'},
#   {'id': 52,
#    'std_add': {'street': 'đường 8c',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 8c bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 8c binh chanh ho chi minh'},
#   {'id': 53,
#    'std_add': {'street': 'đường 9',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 9 bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 9 binh chanh ho chi minh'},
#   {'id': 54,
#    'std_add': {'street': 'đường 9a',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 9a bình chánh hồ chí minh',
#    'NT_norm_add': 'duong 9a binh chanh ho chi minh'},
#   {'id': 55,
#    'std_add': {'street': 'a1',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'a1 bình chánh hồ chí minh',
#    'NT_norm_add': 'a1 binh chanh ho chi minh'},
#   {'id': 56,
#    'std_add': {'street': 'an hạ',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'an hạ bình chánh hồ chí minh',
#    'NT_norm_add': 'an ha binh chanh ho chi minh'},
#   {'id': 57,
#    'std_add': {'street': 'an phú đông 27',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'an phú đông 27 bình chánh hồ chí minh',
#    'NT_norm_add': 'an phu dong 27 binh chanh ho chi minh'},
#   {'id': 58,
#    'std_add': {'street': 'an phú tây',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'an phú tây bình chánh hồ chí minh',
#    'NT_norm_add': 'an phu tay binh chanh ho chi minh'},
#   {'id': 59,
#    'std_add': {'street': 'b10',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'b10 bình chánh hồ chí minh',
#    'NT_norm_add': 'b10 binh chanh ho chi minh'},
#   {'id': 60,
#    'std_add': {'street': 'b6',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'b6 bình chánh hồ chí minh',
#    'NT_norm_add': 'b6 binh chanh ho chi minh'},
#   {'id': 61,
#    'std_add': {'street': 'bà cả',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'bà cả bình chánh hồ chí minh',
#    'NT_norm_add': 'ba ca binh chanh ho chi minh'},
#   {'id': 62,
#    'std_add': {'street': 'bà hom',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'bà hom bình chánh hồ chí minh',
#    'NT_norm_add': 'ba hom binh chanh ho chi minh'},
#   {'id': 63,
#    'std_add': {'street': 'bà thau',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'bà thau bình chánh hồ chí minh',
#    'NT_norm_add': 'ba thau binh chanh ho chi minh'},
#   {'id': 64,
#    'std_add': {'street': 'bà tỵ',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'bà tỵ bình chánh hồ chí minh',
#    'NT_norm_add': 'ba ty binh chanh ho chi minh'},
#   {'id': 65,
#    'std_add': {'street': 'bến lội',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'bến lội bình chánh hồ chí minh',
#    'NT_norm_add': 'ben loi binh chanh ho chi minh'},
#   {'id': 66,
#    'std_add': {'street': 'bình trường',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'bình trường bình chánh hồ chí minh',
#    'NT_norm_add': 'binh truong binh chanh ho chi minh'},
#   {'id': 67,
#    'std_add': {'street': 'bờ huệ',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'bờ huệ bình chánh hồ chí minh',
#    'NT_norm_add': 'bo hue binh chanh ho chi minh'},
#   {'id': 68,
#    'std_add': {'street': 'bờ kênh',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'bờ kênh bình chánh hồ chí minh',
#    'NT_norm_add': 'bo kenh binh chanh ho chi minh'},
#   {'id': 69,
#    'std_add': {'street': 'bờ nhà thờ',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'bờ nhà thờ bình chánh hồ chí minh',
#    'NT_norm_add': 'bo nha tho binh chanh ho chi minh'},
#   {'id': 70,
#    'std_add': {'street': 'bờ xe lam',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'bờ xe lam bình chánh hồ chí minh',
#    'NT_norm_add': 'bo xe lam binh chanh ho chi minh'},
#   {'id': 71,
#    'std_add': {'street': 'bông văn dĩa',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'bông văn dĩa bình chánh hồ chí minh',
#    'NT_norm_add': 'bong van dia binh chanh ho chi minh'},
#   {'id': 72,
#    'std_add': {'street': 'bùi thanh khiết',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'bùi thanh khiết bình chánh hồ chí minh',
#    'NT_norm_add': 'bui thanh khiet binh chanh ho chi minh'},
#   {'id': 73,
#    'std_add': {'street': 'bùi văn sự',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'bùi văn sự bình chánh hồ chí minh',
#    'NT_norm_add': 'bui van su binh chanh ho chi minh'},
#   {'id': 74,
#    'std_add': {'street': 'c2',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'c2 bình chánh hồ chí minh',
#    'NT_norm_add': 'c2 binh chanh ho chi minh'},
#   {'id': 75,
#    'std_add': {'street': 'c3',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'c3 bình chánh hồ chí minh',
#    'NT_norm_add': 'c3 binh chanh ho chi minh'},
#   {'id': 76,
#    'std_add': {'street': 'c4',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'c4 bình chánh hồ chí minh',
#    'NT_norm_add': 'c4 binh chanh ho chi minh'},
#   {'id': 77,
#    'std_add': {'street': 'c7',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'c7 bình chánh hồ chí minh',
#    'NT_norm_add': 'c7 binh chanh ho chi minh'},
#   {'id': 78,
#    'std_add': {'street': 'c9',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'c9 bình chánh hồ chí minh',
#    'NT_norm_add': 'c9 binh chanh ho chi minh'},
#   {'id': 79,
#    'std_add': {'street': 'cao lỗ',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'cao lỗ bình chánh hồ chí minh',
#    'NT_norm_add': 'cao lo binh chanh ho chi minh'},
#   {'id': 80,
#    'std_add': {'street': 'cầu suối',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'cầu suối bình chánh hồ chí minh',
#    'NT_norm_add': 'cau suoi binh chanh ho chi minh'},
#   {'id': 81,
#    'std_add': {'street': 'cây bàn',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'cây bàn bình chánh hồ chí minh',
#    'NT_norm_add': 'cay ban binh chanh ho chi minh'},
#   {'id': 82,
#    'std_add': {'street': 'cây bàng',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'cây bàng bình chánh hồ chí minh',
#    'NT_norm_add': 'cay bang binh chanh ho chi minh'},
#   {'id': 83,
#    'std_add': {'street': 'cây cám',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'cây cám bình chánh hồ chí minh',
#    'NT_norm_add': 'cay cam binh chanh ho chi minh'},
#   {'id': 84,
#    'std_add': {'street': 'cây dương',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'cây dương bình chánh hồ chí minh',
#    'NT_norm_add': 'cay duong binh chanh ho chi minh'},
#   {'id': 85,
#    'std_add': {'street': 'chánh hưng',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'chánh hưng bình chánh hồ chí minh',
#    'NT_norm_add': 'chanh hung binh chanh ho chi minh'},
#   {'id': 86,
#    'std_add': {'street': 'chiến lược',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'chiến lược bình chánh hồ chí minh',
#    'NT_norm_add': 'chien luoc binh chanh ho chi minh'},
#   {'id': 87,
#    'std_add': {'street': 'chùa',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'chùa bình chánh hồ chí minh',
#    'NT_norm_add': 'chua binh chanh ho chi minh'},
#   {'id': 88,
#    'std_add': {'street': 'công nghệ mới',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'công nghệ mới bình chánh hồ chí minh',
#    'NT_norm_add': 'cong nghe moi binh chanh ho chi minh'},
#   {'id': 89,
#    'std_add': {'street': 'd17',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'd17 bình chánh hồ chí minh',
#    'NT_norm_add': 'd17 binh chanh ho chi minh'},
#   {'id': 90,
#    'std_add': {'street': 'd2',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'd2 bình chánh hồ chí minh',
#    'NT_norm_add': 'd2 binh chanh ho chi minh'},
#   {'id': 91,
#    'std_add': {'street': 'd6',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'd6 bình chánh hồ chí minh',
#    'NT_norm_add': 'd6 binh chanh ho chi minh'},
#   {'id': 92,
#    'std_add': {'street': 'đa phước',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đa phước bình chánh hồ chí minh',
#    'NT_norm_add': 'da phuoc binh chanh ho chi minh'},
#   {'id': 93,
#    'std_add': {'street': 'đinh đức thiện',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đinh đức thiện bình chánh hồ chí minh',
#    'NT_norm_add': 'dinh duc thien binh chanh ho chi minh'},
#   {'id': 94,
#    'std_add': {'street': 'đoàn nguyễn tuân',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đoàn nguyễn tuân bình chánh hồ chí minh',
#    'NT_norm_add': 'doan nguyen tuan binh chanh ho chi minh'},
#   {'id': 95,
#    'std_add': {'street': 'đoàn nguyễn tuấn',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đoàn nguyễn tuấn bình chánh hồ chí minh',
#    'NT_norm_add': 'doan nguyen tuan binh chanh ho chi minh'},
#   {'id': 96,
#    'std_add': {'street': 'đông hưng thuận 6',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đông hưng thuận 6 bình chánh hồ chí minh',
#    'NT_norm_add': 'dong hung thuan 6 binh chanh ho chi minh'},
#   {'id': 97,
#    'std_add': {'street': 'đường đất',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường đất bình chánh hồ chí minh',
#    'NT_norm_add': 'duong dat binh chanh ho chi minh'},
#   {'id': 98,
#    'std_add': {'street': 'dương đình cúc',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'dương đình cúc bình chánh hồ chí minh',
#    'NT_norm_add': 'duong dinh cuc binh chanh ho chi minh'},
#   {'id': 99,
#    'std_add': {'street': 'g6',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'g6 bình chánh hồ chí minh',
#    'NT_norm_add': 'g6 binh chanh ho chi minh'},
#   {'id': 100,
#    'std_add': {'street': 'g7',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'g7 bình chánh hồ chí minh',
#    'NT_norm_add': 'g7 binh chanh ho chi minh'},
#   {'id': 101,
#    'std_add': {'street': 'giao thông hào',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'giao thông hào bình chánh hồ chí minh',
#    'NT_norm_add': 'giao thong hao binh chanh ho chi minh'},
#   {'id': 102,
#    'std_add': {'street': 'hà thanh',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'hà thanh bình chánh hồ chí minh',
#    'NT_norm_add': 'ha thanh binh chanh ho chi minh'},
#   {'id': 103,
#    'std_add': {'street': 'hàng cọ',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'hàng cọ bình chánh hồ chí minh',
#    'NT_norm_add': 'hang co binh chanh ho chi minh'},
#   {'id': 104,
#    'std_add': {'street': 'hàng cọ 9a',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'hàng cọ 9a bình chánh hồ chí minh',
#    'NT_norm_add': 'hang co 9a binh chanh ho chi minh'},
#   {'id': 105,
#    'std_add': {'street': 'hậu lân',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'hậu lân bình chánh hồ chí minh',
#    'NT_norm_add': 'hau lan binh chanh ho chi minh'},
#   {'id': 106,
#    'std_add': {'street': 'hiệp thành 13',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'hiệp thành 13 bình chánh hồ chí minh',
#    'NT_norm_add': 'hiep thanh 13 binh chanh ho chi minh'},
#   {'id': 107,
#    'std_add': {'street': 'hiệp thành 7',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'hiệp thành 7 bình chánh hồ chí minh',
#    'NT_norm_add': 'hiep thanh 7 binh chanh ho chi minh'},
#   {'id': 108,
#    'std_add': {'street': 'hoàng đạo thúy',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'hoàng đạo thúy bình chánh hồ chí minh',
#    'NT_norm_add': 'hoang dao thuy binh chanh ho chi minh'},
#   {'id': 109,
#    'std_add': {'street': 'hoàng phan thái',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'hoàng phan thái bình chánh hồ chí minh',
#    'NT_norm_add': 'hoang phan thai binh chanh ho chi minh'},
#   {'id': 110,
#    'std_add': {'street': 'hóc hữu',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'hóc hữu bình chánh hồ chí minh',
#    'NT_norm_add': 'hoc huu binh chanh ho chi minh'},
#   {'id': 111,
#    'std_add': {'street': 'hưng long',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'hưng long bình chánh hồ chí minh',
#    'NT_norm_add': 'hung long binh chanh ho chi minh'},
#   {'id': 112,
#    'std_add': {'street': 'hưng nhơn',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'hưng nhơn bình chánh hồ chí minh',
#    'NT_norm_add': 'hung nhon binh chanh ho chi minh'},
#   {'id': 113,
#    'std_add': {'street': 'hương lộ  80',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'hương lộ  80 bình chánh hồ chí minh',
#    'NT_norm_add': 'huong lo  80 binh chanh ho chi minh'},
#   {'id': 114,
#    'std_add': {'street': 'hương lộ 11',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'hương lộ 11 bình chánh hồ chí minh',
#    'NT_norm_add': 'huong lo 11 binh chanh ho chi minh'},
#   {'id': 115,
#    'std_add': {'street': 'hương lộ 14',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'hương lộ 14 bình chánh hồ chí minh',
#    'NT_norm_add': 'huong lo 14 binh chanh ho chi minh'},
#   {'id': 116,
#    'std_add': {'street': 'huỳnh bá chánh',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'huỳnh bá chánh bình chánh hồ chí minh',
#    'NT_norm_add': 'huynh ba chanh binh chanh ho chi minh'},
#   {'id': 117,
#    'std_add': {'street': 'huỳnh hữu trí',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'huỳnh hữu trí bình chánh hồ chí minh',
#    'NT_norm_add': 'huynh huu tri binh chanh ho chi minh'},
#   {'id': 118,
#    'std_add': {'street': 'huỳnh văn trí',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'huỳnh văn trí bình chánh hồ chí minh',
#    'NT_norm_add': 'huynh van tri binh chanh ho chi minh'},
#   {'id': 119,
#    'std_add': {'street': 'kênh',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'kênh bình chánh hồ chí minh',
#    'NT_norm_add': 'kenh binh chanh ho chi minh'},
#   {'id': 120,
#    'std_add': {'street': 'kênh 10',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'kênh 10 bình chánh hồ chí minh',
#    'NT_norm_add': 'kenh 10 binh chanh ho chi minh'},
#   {'id': 121,
#    'std_add': {'street': 'kênh 7',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'kênh 7 bình chánh hồ chí minh',
#    'NT_norm_add': 'kenh 7 binh chanh ho chi minh'},
#   {'id': 122,
#    'std_add': {'street': 'kênh 8',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'kênh 8 bình chánh hồ chí minh',
#    'NT_norm_add': 'kenh 8 binh chanh ho chi minh'},
#   {'id': 123,
#    'std_add': {'street': 'kênh 9',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'kênh 9 bình chánh hồ chí minh',
#    'NT_norm_add': 'kenh 9 binh chanh ho chi minh'},
#   {'id': 124,
#    'std_add': {'street': 'kênh a',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'kênh a bình chánh hồ chí minh',
#    'NT_norm_add': 'kenh a binh chanh ho chi minh'},
#   {'id': 125,
#    'std_add': {'street': 'kênh c',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'kênh c bình chánh hồ chí minh',
#    'NT_norm_add': 'kenh c binh chanh ho chi minh'},
#   {'id': 126,
#    'std_add': {'street': 'kênh trung ương',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'kênh trung ương bình chánh hồ chí minh',
#    'NT_norm_add': 'kenh trung uong binh chanh ho chi minh'},
#   {'id': 127,
#    'std_add': {'street': 'khuất văn bức',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'khuất văn bức bình chánh hồ chí minh',
#    'NT_norm_add': 'khuat van buc binh chanh ho chi minh'},
#   {'id': 128,
#    'std_add': {'street': 'kinh 11',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'kinh 11 bình chánh hồ chí minh',
#    'NT_norm_add': 'kinh 11 binh chanh ho chi minh'},
#   {'id': 129,
#    'std_add': {'street': 'kinh 4',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'kinh 4 bình chánh hồ chí minh',
#    'NT_norm_add': 'kinh 4 binh chanh ho chi minh'},
#   {'id': 130,
#    'std_add': {'street': 'kinh 6',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'kinh 6 bình chánh hồ chí minh',
#    'NT_norm_add': 'kinh 6 binh chanh ho chi minh'},
#   {'id': 131,
#    'std_add': {'street': 'kinh a',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'kinh a bình chánh hồ chí minh',
#    'NT_norm_add': 'kinh a binh chanh ho chi minh'},
#   {'id': 132,
#    'std_add': {'street': 'kinh b12',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'kinh b12 bình chánh hồ chí minh',
#    'NT_norm_add': 'kinh b12 binh chanh ho chi minh'},
#   {'id': 133,
#    'std_add': {'street': 'kinh rau răm',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'kinh rau răm bình chánh hồ chí minh',
#    'NT_norm_add': 'kinh rau ram binh chanh ho chi minh'},
#   {'id': 134,
#    'std_add': {'street': 'kinh trung ương',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'kinh trung ương bình chánh hồ chí minh',
#    'NT_norm_add': 'kinh trung uong binh chanh ho chi minh'},
#   {'id': 135,
#    'std_add': {'street': 'lại hùng cường',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'lại hùng cường bình chánh hồ chí minh',
#    'NT_norm_add': 'lai hung cuong binh chanh ho chi minh'},
#   {'id': 136,
#    'std_add': {'street': 'láng le bàu cò',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'láng le bàu cò bình chánh hồ chí minh',
#    'NT_norm_add': 'lang le bau co binh chanh ho chi minh'},
#   {'id': 137,
#    'std_add': {'street': 'lê chân',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'lê chân bình chánh hồ chí minh',
#    'NT_norm_add': 'le chan binh chanh ho chi minh'},
#   {'id': 138,
#    'std_add': {'street': 'lê chính đang',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'lê chính đang bình chánh hồ chí minh',
#    'NT_norm_add': 'le chinh dang binh chanh ho chi minh'},
#   {'id': 139,
#    'std_add': {'street': 'lê đình chi',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'lê đình chi bình chánh hồ chí minh',
#    'NT_norm_add': 'le dinh chi binh chanh ho chi minh'},
#   {'id': 140,
#    'std_add': {'street': 'lê minh xuân',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'lê minh xuân bình chánh hồ chí minh',
#    'NT_norm_add': 'le minh xuan binh chanh ho chi minh'},
#   {'id': 141,
#    'std_add': {'street': 'lê quý hoàn',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'lê quý hoàn bình chánh hồ chí minh',
#    'NT_norm_add': 'le quy hoan binh chanh ho chi minh'},
#   {'id': 142,
#    'std_add': {'street': 'liên ấp',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'liên ấp bình chánh hồ chí minh',
#    'NT_norm_add': 'lien ap binh chanh ho chi minh'},
#   {'id': 143,
#    'std_add': {'street': 'liên ấp 1-2',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'liên ấp 1-2 bình chánh hồ chí minh',
#    'NT_norm_add': 'lien ap 1-2 binh chanh ho chi minh'},
#   {'id': 144,
#    'std_add': {'street': 'liên ấp 123',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'liên ấp 123 bình chánh hồ chí minh',
#    'NT_norm_add': 'lien ap 123 binh chanh ho chi minh'},
#   {'id': 145,
#    'std_add': {'street': 'liên ấp 2-3',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'liên ấp 2-3 bình chánh hồ chí minh',
#    'NT_norm_add': 'lien ap 2-3 binh chanh ho chi minh'},
#   {'id': 146,
#    'std_add': {'street': 'liên ấp 2-3-4',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'liên ấp 2-3-4 bình chánh hồ chí minh',
#    'NT_norm_add': 'lien ap 2-3-4 binh chanh ho chi minh'},
#   {'id': 147,
#    'std_add': {'street': 'liên ấp 2-6',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'liên ấp 2-6 bình chánh hồ chí minh',
#    'NT_norm_add': 'lien ap 2-6 binh chanh ho chi minh'},
#   {'id': 148,
#    'std_add': {'street': 'liên ấp 3-4-5',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'liên ấp 3-4-5 bình chánh hồ chí minh',
#    'NT_norm_add': 'lien ap 3-4-5 binh chanh ho chi minh'},
#   {'id': 149,
#    'std_add': {'street': 'liên ấp 4-5',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'liên ấp 4-5 bình chánh hồ chí minh',
#    'NT_norm_add': 'lien ap 4-5 binh chanh ho chi minh'},
#   {'id': 150,
#    'std_add': {'street': 'liên ấp 5-6',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'liên ấp 5-6 bình chánh hồ chí minh',
#    'NT_norm_add': 'lien ap 5-6 binh chanh ho chi minh'},
#   {'id': 151,
#    'std_add': {'street': 'liên ấp 6',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'liên ấp 6 bình chánh hồ chí minh',
#    'NT_norm_add': 'lien ap 6 binh chanh ho chi minh'},
#   {'id': 152,
#    'std_add': {'street': 'liên ấp 6-2',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'liên ấp 6-2 bình chánh hồ chí minh',
#    'NT_norm_add': 'lien ap 6-2 binh chanh ho chi minh'},
#   {'id': 153,
#    'std_add': {'street': 'liên khu 123',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'liên khu 123 bình chánh hồ chí minh',
#    'NT_norm_add': 'lien khu 123 binh chanh ho chi minh'},
#   {'id': 154,
#    'std_add': {'street': 'liên khu 2-6',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'liên khu 2-6 bình chánh hồ chí minh',
#    'NT_norm_add': 'lien khu 2-6 binh chanh ho chi minh'},
#   {'id': 155,
#    'std_add': {'street': 'liên khu 4-5',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'liên khu 4-5 bình chánh hồ chí minh',
#    'NT_norm_add': 'lien khu 4-5 binh chanh ho chi minh'},
#   {'id': 156,
#    'std_add': {'street': 'liên khu 5 - 6',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'liên khu 5 - 6 bình chánh hồ chí minh',
#    'NT_norm_add': 'lien khu 5 - 6 binh chanh ho chi minh'},
#   {'id': 157,
#    'std_add': {'street': 'liên thôn 1-2-3',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'liên thôn 1-2-3 bình chánh hồ chí minh',
#    'NT_norm_add': 'lien thon 1-2-3 binh chanh ho chi minh'},
#   {'id': 158,
#    'std_add': {'street': 'linh hòa',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'linh hòa bình chánh hồ chí minh',
#    'NT_norm_add': 'linh hoa binh chanh ho chi minh'},
#   {'id': 159,
#    'std_add': {'street': 'lô 2',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'lô 2 bình chánh hồ chí minh',
#    'NT_norm_add': 'lo 2 binh chanh ho chi minh'},
#   {'id': 160,
#    'std_add': {'street': 'lộc hòa',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'lộc hòa bình chánh hồ chí minh',
#    'NT_norm_add': 'loc hoa binh chanh ho chi minh'},
#   {'id': 161,
#    'std_add': {'street': 'lương định của',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'lương định của bình chánh hồ chí minh',
#    'NT_norm_add': 'luong dinh cua binh chanh ho chi minh'},
#   {'id': 162,
#    'std_add': {'street': 'lý ông trọng',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'lý ông trọng bình chánh hồ chí minh',
#    'NT_norm_add': 'ly ong trong binh chanh ho chi minh'},
#   {'id': 163,
#    'std_add': {'street': 'mai bá hương',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'mai bá hương bình chánh hồ chí minh',
#    'NT_norm_add': 'mai ba huong binh chanh ho chi minh'},
#   {'id': 164,
#    'std_add': {'street': 'mương khai',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'mương khai bình chánh hồ chí minh',
#    'NT_norm_add': 'muong khai binh chanh ho chi minh'},
#   {'id': 165,
#    'std_add': {'street': 'nguyễn an ninh',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'nguyễn an ninh bình chánh hồ chí minh',
#    'NT_norm_add': 'nguyen an ninh binh chanh ho chi minh'},
#   {'id': 166,
#    'std_add': {'street': 'nguyễn cửu phú',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'nguyễn cửu phú bình chánh hồ chí minh',
#    'NT_norm_add': 'nguyen cuu phu binh chanh ho chi minh'},
#   {'id': 167,
#    'std_add': {'street': 'nguyễn đình kiên',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'nguyễn đình kiên bình chánh hồ chí minh',
#    'NT_norm_add': 'nguyen dinh kien binh chanh ho chi minh'},
#   {'id': 168,
#    'std_add': {'street': 'nguyễn đoàn tuân',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'nguyễn đoàn tuân bình chánh hồ chí minh',
#    'NT_norm_add': 'nguyen doan tuan binh chanh ho chi minh'},
#   {'id': 169,
#    'std_add': {'street': 'nguyễn hữu trí',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'nguyễn hữu trí bình chánh hồ chí minh',
#    'NT_norm_add': 'nguyen huu tri binh chanh ho chi minh'},
#   {'id': 170,
#    'std_add': {'street': 'nguyễn huy chương',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'nguyễn huy chương bình chánh hồ chí minh',
#    'NT_norm_add': 'nguyen huy chuong binh chanh ho chi minh'},
#   {'id': 171,
#    'std_add': {'street': 'nguyễn khanh',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'nguyễn khanh bình chánh hồ chí minh',
#    'NT_norm_add': 'nguyen khanh binh chanh ho chi minh'},
#   {'id': 172,
#    'std_add': {'street': 'nguyễn thái bình',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'nguyễn thái bình bình chánh hồ chí minh',
#    'NT_norm_add': 'nguyen thai binh binh chanh ho chi minh'},
#   {'id': 173,
#    'std_add': {'street': 'nguyễn thị dung',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'nguyễn thị dung bình chánh hồ chí minh',
#    'NT_norm_add': 'nguyen thi dung binh chanh ho chi minh'},
#   {'id': 174,
#    'std_add': {'street': 'nguyễn thị sưa',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'nguyễn thị sưa bình chánh hồ chí minh',
#    'NT_norm_add': 'nguyen thi sua binh chanh ho chi minh'},
#   {'id': 175,
#    'std_add': {'street': 'nguyễn thị thập',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'nguyễn thị thập bình chánh hồ chí minh',
#    'NT_norm_add': 'nguyen thi thap binh chanh ho chi minh'},
#   {'id': 176,
#    'std_add': {'street': 'nguyễn thị tú',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'nguyễn thị tú bình chánh hồ chí minh',
#    'NT_norm_add': 'nguyen thi tu binh chanh ho chi minh'},
#   {'id': 177,
#    'std_add': {'street': 'nguyễn tri phương',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'nguyễn tri phương bình chánh hồ chí minh',
#    'NT_norm_add': 'nguyen tri phuong binh chanh ho chi minh'},
#   {'id': 178,
#    'std_add': {'street': 'nguyễn văn bứa',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'nguyễn văn bứa bình chánh hồ chí minh',
#    'NT_norm_add': 'nguyen van bua binh chanh ho chi minh'},
#   {'id': 179,
#    'std_add': {'street': 'nguyễn văn cừ',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'nguyễn văn cừ bình chánh hồ chí minh',
#    'NT_norm_add': 'nguyen van cu binh chanh ho chi minh'},
#   {'id': 180,
#    'std_add': {'street': 'nguyễn văn linh',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'nguyễn văn linh bình chánh hồ chí minh',
#    'NT_norm_add': 'nguyen van linh binh chanh ho chi minh'},
#   {'id': 181,
#    'std_add': {'street': 'nguyễn văn long',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'nguyễn văn long bình chánh hồ chí minh',
#    'NT_norm_add': 'nguyen van long binh chanh ho chi minh'},
#   {'id': 182,
#    'std_add': {'street': 'nguyễn văn thời',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'nguyễn văn thời bình chánh hồ chí minh',
#    'NT_norm_add': 'nguyen van thoi binh chanh ho chi minh'},
#   {'id': 183,
#    'std_add': {'street': 'nữ dân công',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'nữ dân công bình chánh hồ chí minh',
#    'NT_norm_add': 'nu dan cong binh chanh ho chi minh'},
#   {'id': 184,
#    'std_add': {'street': 'phạm hùng',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'phạm hùng bình chánh hồ chí minh',
#    'NT_norm_add': 'pham hung binh chanh ho chi minh'},
#   {'id': 185,
#    'std_add': {'street': 'phạm tấn mười',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'phạm tấn mười bình chánh hồ chí minh',
#    'NT_norm_add': 'pham tan muoi binh chanh ho chi minh'},
#   {'id': 186,
#    'std_add': {'street': 'phạm văn sáng',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'phạm văn sáng bình chánh hồ chí minh',
#    'NT_norm_add': 'pham van sang binh chanh ho chi minh'},
#   {'id': 187,
#    'std_add': {'street': 'phạm văn thuận',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'phạm văn thuận bình chánh hồ chí minh',
#    'NT_norm_add': 'pham van thuan binh chanh ho chi minh'},
#   {'id': 188,
#    'std_add': {'street': 'phan văn mảng',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'phan văn mảng bình chánh hồ chí minh',
#    'NT_norm_add': 'phan van mang binh chanh ho chi minh'},
#   {'id': 189,
#    'std_add': {'street': 'phước lý',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'phước lý bình chánh hồ chí minh',
#    'NT_norm_add': 'phuoc ly binh chanh ho chi minh'},
#   {'id': 190,
#    'std_add': {'street': 'quách điêu',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'quách điêu bình chánh hồ chí minh',
#    'NT_norm_add': 'quach dieu binh chanh ho chi minh'},
#   {'id': 191,
#    'std_add': {'street': 'quốc lộ 1a',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'quốc lộ 1a bình chánh hồ chí minh',
#    'NT_norm_add': 'quoc lo 1a binh chanh ho chi minh'},
#   {'id': 192,
#    'std_add': {'street': 'quốc lộ 2',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'quốc lộ 2 bình chánh hồ chí minh',
#    'NT_norm_add': 'quoc lo 2 binh chanh ho chi minh'},
#   {'id': 193,
#    'std_add': {'street': 'quốc lộ 50',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'quốc lộ 50 bình chánh hồ chí minh',
#    'NT_norm_add': 'quoc lo 50 binh chanh ho chi minh'},
#   {'id': 194,
#    'std_add': {'street': 'quốc lộ 80',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'quốc lộ 80 bình chánh hồ chí minh',
#    'NT_norm_add': 'quoc lo 80 binh chanh ho chi minh'},
#   {'id': 195,
#    'std_add': {'street': 'quốc lộ 8a',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'quốc lộ 8a bình chánh hồ chí minh',
#    'NT_norm_add': 'quoc lo 8a binh chanh ho chi minh'},
#   {'id': 196,
#    'std_add': {'street': 'rạch bà lớn',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'rạch bà lớn bình chánh hồ chí minh',
#    'NT_norm_add': 'rach ba lon binh chanh ho chi minh'},
#   {'id': 197,
#    'std_add': {'street': 'rạch bàu gốc',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'rạch bàu gốc bình chánh hồ chí minh',
#    'NT_norm_add': 'rach bau goc binh chanh ho chi minh'},
#   {'id': 198,
#    'std_add': {'street': 'rạch cầu suối',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'rạch cầu suối bình chánh hồ chí minh',
#    'NT_norm_add': 'rach cau suoi binh chanh ho chi minh'},
#   {'id': 199,
#    'std_add': {'street': 'rạch ông đồ',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'rạch ông đồ bình chánh hồ chí minh',
#    'NT_norm_add': 'rach ong do binh chanh ho chi minh'},
#   {'id': 200,
#    'std_add': {'street': 'số 1',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'số 1 bình chánh hồ chí minh',
#    'NT_norm_add': 'so 1 binh chanh ho chi minh'},
#   {'id': 201,
#    'std_add': {'street': 'số 10',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'số 10 bình chánh hồ chí minh',
#    'NT_norm_add': 'so 10 binh chanh ho chi minh'},
#   {'id': 202,
#    'std_add': {'street': 'số 11',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'số 11 bình chánh hồ chí minh',
#    'NT_norm_add': 'so 11 binh chanh ho chi minh'},
#   {'id': 203,
#    'std_add': {'street': 'số 12',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'số 12 bình chánh hồ chí minh',
#    'NT_norm_add': 'so 12 binh chanh ho chi minh'},
#   {'id': 204,
#    'std_add': {'street': 'số 12b',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'số 12b bình chánh hồ chí minh',
#    'NT_norm_add': 'so 12b binh chanh ho chi minh'},
#   {'id': 205,
#    'std_add': {'street': 'số 13',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'số 13 bình chánh hồ chí minh',
#    'NT_norm_add': 'so 13 binh chanh ho chi minh'},
#   {'id': 206,
#    'std_add': {'street': 'số 14',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'số 14 bình chánh hồ chí minh',
#    'NT_norm_add': 'so 14 binh chanh ho chi minh'},
#   {'id': 207,
#    'std_add': {'street': 'số 16',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'số 16 bình chánh hồ chí minh',
#    'NT_norm_add': 'so 16 binh chanh ho chi minh'},
#   {'id': 208,
#    'std_add': {'street': 'số 18',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'số 18 bình chánh hồ chí minh',
#    'NT_norm_add': 'so 18 binh chanh ho chi minh'},
#   {'id': 209,
#    'std_add': {'street': 'số 19',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'số 19 bình chánh hồ chí minh',
#    'NT_norm_add': 'so 19 binh chanh ho chi minh'},
#   {'id': 210,
#    'std_add': {'street': 'số 1a',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'số 1a bình chánh hồ chí minh',
#    'NT_norm_add': 'so 1a binh chanh ho chi minh'},
#   {'id': 211,
#    'std_add': {'street': 'số 1e',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'số 1e bình chánh hồ chí minh',
#    'NT_norm_add': 'so 1e binh chanh ho chi minh'},
#   {'id': 212,
#    'std_add': {'street': 'số 2',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'số 2 bình chánh hồ chí minh',
#    'NT_norm_add': 'so 2 binh chanh ho chi minh'},
#   {'id': 213,
#    'std_add': {'street': 'số 24',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'số 24 bình chánh hồ chí minh',
#    'NT_norm_add': 'so 24 binh chanh ho chi minh'},
#   {'id': 214,
#    'std_add': {'street': 'số 3',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'số 3 bình chánh hồ chí minh',
#    'NT_norm_add': 'so 3 binh chanh ho chi minh'},
#   {'id': 215,
#    'std_add': {'street': 'số 4',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'số 4 bình chánh hồ chí minh',
#    'NT_norm_add': 'so 4 binh chanh ho chi minh'},
#   {'id': 216,
#    'std_add': {'street': 'số 5',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'số 5 bình chánh hồ chí minh',
#    'NT_norm_add': 'so 5 binh chanh ho chi minh'},
#   {'id': 217,
#    'std_add': {'street': 'số 6',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'số 6 bình chánh hồ chí minh',
#    'NT_norm_add': 'so 6 binh chanh ho chi minh'},
#   {'id': 218,
#    'std_add': {'street': 'số 6a',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'số 6a bình chánh hồ chí minh',
#    'NT_norm_add': 'so 6a binh chanh ho chi minh'},
#   {'id': 219,
#    'std_add': {'street': 'số 6b',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'số 6b bình chánh hồ chí minh',
#    'NT_norm_add': 'so 6b binh chanh ho chi minh'},
#   {'id': 220,
#    'std_add': {'street': 'số 6d',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'số 6d bình chánh hồ chí minh',
#    'NT_norm_add': 'so 6d binh chanh ho chi minh'},
#   {'id': 221,
#    'std_add': {'street': 'số 7',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
#    'norm_add': 'số 7 bình chánh hồ chí minh',
#    'NT_norm_add': 'so 7 binh chanh ho chi minh'},
#   {'id': 222,
#    'std_add': {'street': 'số 8',
#     'district': 'bình chánh',
#     'city': 'hồ chí minh'},
# ...
#   {'id': 1061,
#    'std_add': {'ward': 'tam thôn hiệp',
#     'district': 'cần giờ',
#     'city': 'hồ chí minh'},
#    'norm_add': 'tam thôn hiệp cần giờ hồ chí minh',
#    'NT_norm_add': 'tam thon hiep can gio ho chi minh'},
#   {'id': 1062,
#    'std_add': {'ward': 'thạnh an',
#     'district': 'cần giờ',
#     'city': 'hồ chí minh'},
#    'norm_add': 'thạnh an cần giờ hồ chí minh',
#    'NT_norm_add': 'thanh an can gio ho chi minh'},
#   {'id': 1063,
#    'std_add': {'street': 'đường 1',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 1 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 1 cu chi ho chi minh'},
#   {'id': 1064,
#    'std_add': {'street': 'đường 101',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 101 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 101 cu chi ho chi minh'},
#   {'id': 1065,
#    'std_add': {'street': 'đường 11',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 11 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 11 cu chi ho chi minh'},
#   {'id': 1066,
#    'std_add': {'street': 'đường 110',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 110 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 110 cu chi ho chi minh'},
#   {'id': 1067,
#    'std_add': {'street': 'đường 112',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 112 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 112 cu chi ho chi minh'},
#   {'id': 1068,
#    'std_add': {'street': 'đường 118',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 118 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 118 cu chi ho chi minh'},
#   {'id': 1069,
#    'std_add': {'street': 'đường 13',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 13 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 13 cu chi ho chi minh'},
#   {'id': 1070,
#    'std_add': {'street': 'đường 131',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 131 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 131 cu chi ho chi minh'},
#   {'id': 1071,
#    'std_add': {'street': 'đường 15',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 15 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 15 cu chi ho chi minh'},
#   {'id': 1072,
#    'std_add': {'street': 'đường 18',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 18 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 18 cu chi ho chi minh'},
#   {'id': 1073,
#    'std_add': {'street': 'đường 19/5',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 19/5 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 19/5 cu chi ho chi minh'},
#   {'id': 1074,
#    'std_add': {'street': 'đường 2',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 2 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 2 cu chi ho chi minh'},
#   {'id': 1075,
#    'std_add': {'street': 'đường 20',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 20 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 20 cu chi ho chi minh'},
#   {'id': 1076,
#    'std_add': {'street': 'đường 21',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 21 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 21 cu chi ho chi minh'},
#   {'id': 1077,
#    'std_add': {'street': 'đường 212',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 212 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 212 cu chi ho chi minh'},
#   {'id': 1078,
#    'std_add': {'street': 'đường 22',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 22 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 22 cu chi ho chi minh'},
#   {'id': 1079,
#    'std_add': {'street': 'đường 26',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 26 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 26 cu chi ho chi minh'},
#   {'id': 1080,
#    'std_add': {'street': 'đường 28',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 28 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 28 cu chi ho chi minh'},
#   {'id': 1081,
#    'std_add': {'street': 'đường 32',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 32 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 32 cu chi ho chi minh'},
#   {'id': 1082,
#    'std_add': {'street': 'đường 33',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 33 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 33 cu chi ho chi minh'},
#   {'id': 1083,
#    'std_add': {'street': 'đường 355',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 355 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 355 cu chi ho chi minh'},
#   {'id': 1084,
#    'std_add': {'street': 'đường 36',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 36 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 36 cu chi ho chi minh'},
#   {'id': 1085,
#    'std_add': {'street': 'đường 363',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 363 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 363 cu chi ho chi minh'},
#   {'id': 1086,
#    'std_add': {'street': 'đường 365',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 365 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 365 cu chi ho chi minh'},
#   {'id': 1087,
#    'std_add': {'street': 'đường 367',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 367 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 367 cu chi ho chi minh'},
#   {'id': 1088,
#    'std_add': {'street': 'đường 39',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 39 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 39 cu chi ho chi minh'},
#   {'id': 1089,
#    'std_add': {'street': 'đường 40',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 40 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 40 cu chi ho chi minh'},
#   {'id': 1090,
#    'std_add': {'street': 'đường 41',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 41 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 41 cu chi ho chi minh'},
#   {'id': 1091,
#    'std_add': {'street': 'đường 43',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 43 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 43 cu chi ho chi minh'},
#   {'id': 1092,
#    'std_add': {'street': 'đường 441',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 441 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 441 cu chi ho chi minh'},
#   {'id': 1093,
#    'std_add': {'street': 'đường 458',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 458 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 458 cu chi ho chi minh'},
#   {'id': 1094,
#    'std_add': {'street': 'đường 47',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 47 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 47 cu chi ho chi minh'},
#   {'id': 1095,
#    'std_add': {'street': 'đường 489',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 489 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 489 cu chi ho chi minh'},
#   {'id': 1096,
#    'std_add': {'street': 'đường 490',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 490 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 490 cu chi ho chi minh'},
#   {'id': 1097,
#    'std_add': {'street': 'đường 5',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 5 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 5 cu chi ho chi minh'},
#   {'id': 1098,
#    'std_add': {'street': 'đường 51',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 51 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 51 cu chi ho chi minh'},
#   {'id': 1099,
#    'std_add': {'street': 'đường 53',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 53 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 53 cu chi ho chi minh'},
#   {'id': 1100,
#    'std_add': {'street': 'đường 540',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 540 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 540 cu chi ho chi minh'},
#   {'id': 1101,
#    'std_add': {'street': 'đường 572',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 572 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 572 cu chi ho chi minh'},
#   {'id': 1102,
#    'std_add': {'street': 'đường 6',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 6 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 6 cu chi ho chi minh'},
#   {'id': 1103,
#    'std_add': {'street': 'đường 68',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 68 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 68 cu chi ho chi minh'},
#   {'id': 1104,
#    'std_add': {'street': 'đường 7',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 7 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 7 cu chi ho chi minh'},
#   {'id': 1105,
#    'std_add': {'street': 'đường 702',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 702 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 702 cu chi ho chi minh'},
#   {'id': 1106,
#    'std_add': {'street': 'đường 8',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 8 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 8 cu chi ho chi minh'},
#   {'id': 1107,
#    'std_add': {'street': 'đường 89',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 89 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 89 cu chi ho chi minh'},
#   {'id': 1108,
#    'std_add': {'street': 'đường 9',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 9 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 9 cu chi ho chi minh'},
#   {'id': 1109,
#    'std_add': {'street': 'đường 93',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 93 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 93 cu chi ho chi minh'},
#   {'id': 1110,
#    'std_add': {'street': 'đường 94',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 94 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 94 cu chi ho chi minh'},
#   {'id': 1111,
#    'std_add': {'street': 'đường 96',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 96 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 96 cu chi ho chi minh'},
#   {'id': 1112,
#    'std_add': {'street': 'đường 97',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 97 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 97 cu chi ho chi minh'},
#   {'id': 1113,
#    'std_add': {'street': 'đường 98',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'đường 98 củ chi hồ chí minh',
#    'NT_norm_add': 'duong 98 cu chi ho chi minh'},
#   {'id': 1114,
#    'std_add': {'street': 'an hòa',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'an hòa củ chi hồ chí minh',
#    'NT_norm_add': 'an hoa cu chi ho chi minh'},
#   {'id': 1115,
#    'std_add': {'street': 'an nhơn tây',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'an nhơn tây củ chi hồ chí minh',
#    'NT_norm_add': 'an nhon tay cu chi ho chi minh'},
#   {'id': 1116,
#    'std_add': {'street': 'ba lăng',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'ba lăng củ chi hồ chí minh',
#    'NT_norm_add': 'ba lang cu chi ho chi minh'},
#   {'id': 1117,
#    'std_add': {'street': 'ba sa', 'district': 'củ chi', 'city': 'hồ chí minh'},
#    'norm_add': 'ba sa củ chi hồ chí minh',
#    'NT_norm_add': 'ba sa cu chi ho chi minh'},
#   {'id': 1118,
#    'std_add': {'street': 'bà thiên',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'bà thiên củ chi hồ chí minh',
#    'NT_norm_add': 'ba thien cu chi ho chi minh'},
#   {'id': 1119,
#    'std_add': {'street': 'bàu giã',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'bàu giã củ chi hồ chí minh',
#    'NT_norm_add': 'bau gia cu chi ho chi minh'},
#   {'id': 1120,
#    'std_add': {'street': 'bàu lách',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'bàu lách củ chi hồ chí minh',
#    'NT_norm_add': 'bau lach cu chi ho chi minh'},
#   {'id': 1121,
#    'std_add': {'street': 'bầu trâm',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'bầu trâm củ chi hồ chí minh',
#    'NT_norm_add': 'bau tram cu chi ho chi minh'},
#   {'id': 1122,
#    'std_add': {'street': 'bàu tre',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'bàu tre củ chi hồ chí minh',
#    'NT_norm_add': 'bau tre cu chi ho chi minh'},
#   {'id': 1123,
#    'std_add': {'street': 'bến đình',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'bến đình củ chi hồ chí minh',
#    'NT_norm_add': 'ben dinh cu chi ho chi minh'},
#   {'id': 1124,
#    'std_add': {'street': 'bến đò 1',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'bến đò 1 củ chi hồ chí minh',
#    'NT_norm_add': 'ben do 1 cu chi ho chi minh'},
#   {'id': 1125,
#    'std_add': {'street': 'bến đò 2',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'bến đò 2 củ chi hồ chí minh',
#    'NT_norm_add': 'ben do 2 cu chi ho chi minh'},
#   {'id': 1126,
#    'std_add': {'street': 'bến súc',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'bến súc củ chi hồ chí minh',
#    'NT_norm_add': 'ben suc cu chi ho chi minh'},
#   {'id': 1127,
#    'std_add': {'street': 'bến than',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'bến than củ chi hồ chí minh',
#    'NT_norm_add': 'ben than cu chi ho chi minh'},
#   {'id': 1128,
#    'std_add': {'street': 'bình mỹ',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'bình mỹ củ chi hồ chí minh',
#    'NT_norm_add': 'binh my cu chi ho chi minh'},
#   {'id': 1129,
#    'std_add': {'street': 'bờ kênh',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'bờ kênh củ chi hồ chí minh',
#    'NT_norm_add': 'bo kenh cu chi ho chi minh'},
#   {'id': 1130,
#    'std_add': {'street': 'bùi thị điệt',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'bùi thị điệt củ chi hồ chí minh',
#    'NT_norm_add': 'bui thi diet cu chi ho chi minh'},
#   {'id': 1131,
#    'std_add': {'street': 'bùi thị me',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'bùi thị me củ chi hồ chí minh',
#    'NT_norm_add': 'bui thi me cu chi ho chi minh'},
#   {'id': 1132,
#    'std_add': {'street': 'cá lăng',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'cá lăng củ chi hồ chí minh',
#    'NT_norm_add': 'ca lang cu chi ho chi minh'},
#   {'id': 1133,
#    'std_add': {'street': 'can trường',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'can trường củ chi hồ chí minh',
#    'NT_norm_add': 'can truong cu chi ho chi minh'},
#   {'id': 1134,
#    'std_add': {'street': 'cây bày',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'cây bày củ chi hồ chí minh',
#    'NT_norm_add': 'cay bay cu chi ho chi minh'},
#   {'id': 1135,
#    'std_add': {'street': 'cây da',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'cây da củ chi hồ chí minh',
#    'NT_norm_add': 'cay da cu chi ho chi minh'},
#   {'id': 1136,
#    'std_add': {'street': 'cây gõ',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'cây gõ củ chi hồ chí minh',
#    'NT_norm_add': 'cay go cu chi ho chi minh'},
#   {'id': 1137,
#    'std_add': {'street': 'cây sộp',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'cây sộp củ chi hồ chí minh',
#    'NT_norm_add': 'cay sop cu chi ho chi minh'},
#   {'id': 1138,
#    'std_add': {'street': 'cây trâm',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'cây trâm củ chi hồ chí minh',
#    'NT_norm_add': 'cay tram cu chi ho chi minh'},
#   {'id': 1139,
#    'std_add': {'street': 'cây trôm',
#     'district': 'củ chi',
#     'city': 'hồ chí minh'},
#    'norm_add': 'cây trôm củ chi hồ chí minh',
#    'NT_norm_add': 'cay trom cu chi ho chi minh'},
#   ...]}

# %%
std_addresses = []
for sample in RAT_DATA['data']:
    std_addresses.append(sample['norm_add'])

# %%
# from collections import Counter
# for i in Counter(std_addresses):
#     print(i)
#     break

# %%
x = dict(Counter(std_addresses))
hard_add = []
for i in x:
    if x[i] > 1:
        hard_add.append(i)

# %%
len(hard_add)
# Out:
# 515

# %%
hard_id = []
for sample in RAT_DATA['data']:
    if sample['norm_add'] in hard_add:
        hard_id.append(sample['id'])

# %%
# hard_id

# %%
with open('train.json', 'r', encoding='utf-8') as f:
    data = json.load(f)
hard_sample = []
for sample in data['data']:
    id = (list(sample['std_add'].keys())[0])
    if sample['std_add'][id]['id'] in hard_id:
        hard_sample.append(sample)

# %%
hard_sample
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5520db99db4d> in <module>
# ----> 1 hard_sample
#
# NameError: name 'hard_sample' is not defined

# %%
with open('Siameser/Data/hard_train.json', 'w', encoding='utf-8') as f:
    json.dump(test_data, f, ensure_ascii=False, indent=4)
